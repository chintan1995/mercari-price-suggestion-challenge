# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **DATA INITIZLIZATION**

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import gc

import pandas as pd
import numpy as np
import string
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns
import math
import lightgbm as lgb
from tqdm.notebook import tqdm
tqdm.pandas()

#!pip install Wordbatch
#from wordbatch.models import FTRL, FM_FTRL  # https://github.com/anttttti/Wordbatch
import xgboost  # Version 0.90
# Scikit-learn version 0.22.2.post1
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from nltk.corpus import wordnet
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from sklearn.model_selection import train_test_split
import scipy
from scipy.sparse import hstack

from sklearn.metrics import mean_squared_log_error
import pickle
import regex as re
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/My Drive/Colab Notebooks/'
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
if 'train.tsv' not in os.listdir():
    # !kaggle competitions download -c mercari-price-suggestion-challenge
    get_ipython().system_raw("7z x \*.7z && rm *.7z")
    get_ipython().system_raw("7z x \*.zip && rm *.zip")
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.10 / client 1.5.4)
# Downloading train.tsv.7z to /content
#  66% 49.0M/74.3M [00:01<00:00, 40.6MB/s]
# 100% 74.3M/74.3M [00:01<00:00, 64.1MB/s]
# Downloading sample_submission_stg2.csv.zip to /content
#  64% 5.00M/7.77M [00:00<00:00, 42.8MB/s]
# 100% 7.77M/7.77M [00:00<00:00, 49.6MB/s]
# Downloading sample_submission.csv.7z to /content
#   0% 0.00/170k [00:00<?, ?B/s]
# 100% 170k/170k [00:00<00:00, 156MB/s]
# Downloading test_stg2.tsv.zip to /content
#  98% 289M/294M [00:02<00:00, 149MB/s]
# 100% 294M/294M [00:02<00:00, 116MB/s]
# Downloading test.tsv.7z to /content
#  74% 25.0M/34.0M [00:00<00:00, 29.6MB/s]
# 100% 34.0M/34.0M [00:00<00:00, 69.1MB/s]

# %%
import pandas as pd

train_df = pd.read_csv('train.tsv', sep='\t')

# Price range should be $5-$2000, https://www.mercari.com/us/help_center/article/69
train_df = train_df[train_df['price']>=5]  # Removing the prodicts with prices less than 5
train_df = train_df[train_df['price']<=2000]  # Removing the prodicts with prices more than 2000
train_df.head()
# Out:
#    train_id  ...                                   item_description
# 0         0  ...                                 No description yet
# 1         1  ...  This keyboard is in great condition and works ...
# 2         2  ...  Adorable top with a hint of lace and a key hol...
# 3         3  ...  New with tags. Leather horses. Retail for [rm]...
# 4         4  ...          Complete with certificate of authenticity
#
# [5 rows x 8 columns]

# %% [markdown]
# **Adding log price column**

# %%
from scipy import stats

train_df['log_price'] = np.log(train_df['price'].values)

plt.figure(figsize=(12,10))
plt.subplot(211)
sns.distplot(train_df['log_price'])

# %% [markdown]
# **Train Test Split**

# %%
X = train_df.drop(['train_id','log_price','price'], axis=1)
y = train_df['log_price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=42)
del X, y, train_df

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1374475, 6)
# (1374475,)
# (72341, 6)
# (72341,)

# %%
def evaluate_model(model, X_data, y_act):
    y_pred = model.predict(X_data)

    act_prices = np.round(np.exp(y_act), 2)
    pred_prices = np.round(np.exp(y_pred), 2)

    rms = np.sqrt(mean_squared_log_error(act_prices.values, pred_prices))
    return rms

def do_inference(model, X_te):
  y_pred = model.predict(X_te)
  pred_prices = np.round(np.exp(y_pred), 2)

  return pred_prices

# %% [markdown]
# # **FEATURE ENGINEERING**

# %% [markdown]
# ### **Filling missing values**

# %%
def fill_missing_values(df):
    """
    Description:
    Filling null values in all columns.

    Input: Dataframe with null values
    Output: Dataframe with no null values
    """
    df['name'].fillna('unk_name', inplace=True)
    df['category_name'].fillna('unk_cat', inplace=True)
    df['brand_name'].fillna('unk_brand', inplace=True)
    df['item_description'].fillna('unk_descr', inplace=True)
    return df

# %% [markdown]
# ### **Text Pre-processing**

# %%
import re
import string

def decontract_text(phrase):
    """
    This utility funciton will be used as a part of preprocessing the text.
    It will expand the contracted words. For eg: won't -> will not, I'm -> I am.
    """
    phrase = str(phrase)
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

def preprocess_descriptive_text_column(sentance):
    """
    Description:
    This function will process the text data.
    This function will perform decontracting words, removing stop words, removing special characters and then apply stemming on the words in the sentence.

    Input: original sentence
    Output: processed sentence
    """
    # https://gist.github.com/sebleier/554280
    # we are removing the negative words from the stop words list: 'no', 'nor', 'not', 'shouldn't, won't, etc.
    stopwords= ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",\
                "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', \
                'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',\
                'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', \
                'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', \
                'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', \
                'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',\
                'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further',\
                'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',\
                'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', \
                's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', \
                've', 'y']

    sent = decontract_text(sentance)
    sent = sent.replace('\\r', ' ')
    sent = sent.replace('\\n', ' ')
    sent = sent.replace('\\"', ' ')
    sent = re.sub('[^A-Za-z0-9]+', ' ', sent)
    # https://gist.github.com/sebleier/554280
    sent = ' '.join(e for e in sent.split() if e.lower() not in stopwords)
    sent = sent.lower()
    return sent

# %% [markdown]
# ### **Fill Missing Brand Names**

# %%
import pickle
with open('/content/drive/My Drive/Colab Notebooks/Applied AI Assignments/Case Study 1 Mercari Price Suggestion/brands_list.pkl', 'rb') as f:
    existing_brands = pickle.load(f)
    
with open('/content/drive/My Drive/Colab Notebooks/Applied AI Assignments/Case Study 1 Mercari Price Suggestion/brand_names_categories_dict.pkl', 'rb') as f:
    brand_names_categories = pickle.load(f)

# %%
def brand_guesser(row):
    """
    Description:
    This function is used to guess the missing brand name.
    It will check for an existing brand name mentioned in the item name section. 
    We want our guess to be as close to actual as possible, \
    hence we will also check the category of the brand name that is guessed with the already mentioned category of that product. 
    If the category matches, then only we will fill that guessed brand name.

    Inputs: dataframe row with missing brand names
    Output: dataframe row with filled brand names
    """
    # In the above line, we are creating dictionary of brand name->category, wherever the brand name is missing.
    # This will be helpful to us during guessing the missing brand names.
    brand, name, cn = row
    brand = brand.lower()
    if brand=='unk_brand':
        for brand in existing_brands:
            if brand in name.lower() and cn in brand_names_categories[brand]:
                return brand
            
    return brand

# %% [markdown]
# ### **Split Categories**

# %%
def split_text(text):
    if text=='unk_cat':
        return ["No Label", "No Label", "No Label"]
    return text.split("/")

def split_categories(df):
    """
    Desription:
    This function separates the categories into its three parts. 
    Main category, Sub-category 1 and Sub-category 2
    Then it will remove the original category_name field.

    Input: Dataframe having category_name field
    Output: Dataframe with splitted categories
    """
    df['general_cat'], df['subcat_1'], df['subcat_2'] = zip(*df['category_name'].apply(lambda x: split_text(x)))
    df = df.drop('category_name', axis=1)
    return df

# %% [markdown]
# ### **Adding Item Description len and Item Name len**

# %%
from sklearn.preprocessing import StandardScaler
def get_len_feature(col_series, scaler_text_len=None):
    """
    Description:
    This funciton will calculate the word count of the text and standardize it.

    Input: Series, fitted scaler[optional; used during inference]
    Output: standardized text length for each product and object of the fitted scaler
    """
    text_len = col_series.apply(lambda x: len(x.split()))
    if scaler_text_len==None:
        scaler_text_len = StandardScaler()
        scaler_text_len.fit(text_len.values.reshape(-1, 1))
    text_len = scaler_text_len.transform(text_len.values.reshape(-1, 1))
    return text_len, scaler_text_len

# %% [markdown]
# ### **Add is_expensive**

# %%
def get_is_expensive_feature(df):
    """
    Description:
    This funciton will generate a feature which will tell if the brand is expensive or not.

    Input: Dataframe
    Output: Sparse is_expensive data
    """
    with open('/content/drive/My Drive/Colab Notebooks/Applied AI Assignments/Case Study 1 Mercari Price Suggestion/expensive_brands.pkl', 'rb') as f:
        expensive_brands = pickle.load(f)
    
    df['is_expensive'] = df['brand_name'].apply(lambda x: 1 if x in expensive_brands else 0)
    return df

# %% [markdown]
# ### **Feature Engineering pipeline**

# %%
def feature_pipeline(X_data, scaler_name_len=None, scaler_desc_len=None):
    """
    Description: This function will do all the feature engineering on the input X_data,
                and create a final data, ready for training.

    Input: Original input dataframe, 
                    scalers [optional: used during inference]
    Output: Featurized data
    """
    print()
    print("Filling missing values...")
    X_data = fill_missing_values(X_data)
    
    print("pre-processing text data...")
    X_data['item_description'] = X_data['item_description'].progress_apply(preprocess_descriptive_text_column) ### temp step ###
    X_data['name'] = X_data['name'].progress_apply(preprocess_descriptive_text_column)                         ### temp step ###
    X_data['brand_name'] = X_data['brand_name'].progress_apply(lambda x: str(x).lower())

    print("Guessing the missing brands...")
    X_data['brand_name'] = X_data[['brand_name','name', 'category_name']].progress_apply(brand_guesser, axis = 1)

    print("Splitting categories...")
    X_data = split_categories(X_data)

    print('Getting word lengths')
    X_data['name_len'], scaler_name_len =  get_len_feature(X_data['name'], scaler_name_len)
    X_data['desc_len'], scaler_desc_len =  get_len_feature(X_data['item_description'], scaler_desc_len)

    print("Getting is_expensive brand feature...")
    X_data = get_is_expensive_feature(X_data)

    print("Done!!!\n---------------------------\n")
    return X_data, scaler_name_len, scaler_desc_len

# %% [markdown]
# # **LSTM MODEL**

# %%
from sklearn.preprocessing import Normalizer
import tensorflow as tf
from numpy import array
from numpy import asarray
from numpy import zeros
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import Input, Embedding, Conv1D, MaxPool1D, Flatten, Dropout, Dense, BatchNormalization, Concatenate
from tensorflow.keras.layers import ReLU
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.models import Model
from tensorflow.keras import initializers, regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM, GRU, LayerNormalization

# %%
# How does embedding layer work,
# https://stats.stackexchange.com/questions/270546/how-does-keras-embedding-layer-work

def text_embeddings(text_train, text_test):
    """
    This function does the tokenizing, padding, creating vocab and creating the embedding matrix for text data
    """
    # Word Tokenizer
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(text_train)
    encoded_docs_train = tokenizer.texts_to_sequences(text_train)

    encoded_docs_test = tokenizer.texts_to_sequences(text_test)

    # Getting the 'max len' of doc among the text_train
    len_docs = []
    for doc in text_train:
        splitted_doc = doc.split()
        len_docs.append(len(splitted_doc))
    max_len_doc = max(len_docs)
    #print('max doc len=',max_len_doc) # in terms of words

    text_train_padded = pad_sequences(encoded_docs_train, maxlen=max_len_doc, padding='post')
    text_test_padded = pad_sequences(encoded_docs_test, maxlen=max_len_doc, padding='post')

    vocab_size = len(tokenizer.word_index) + 1
    #print(vocab_size)

    embeddings_index = dict()
    with open('/content/drive/My Drive/Colab Notebooks/Applied AI Assignments/Case Study 1 Mercari Price Suggestion/zzFINAL COMPLETED/FAST TEXT CNN/wiki-news-300d-1M.vec') as f:
        for line in f:
            w_coef = line.rstrip().rsplit(' ')
            word = w_coef[0]
            coefs = asarray(w_coef[1:], dtype='float32')
            embeddings_index[word]=coefs

    embedding_matrix = zeros((vocab_size, 300))
    for word, i in tokenizer.word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
    
    return embedding_matrix, vocab_size, max_len_doc, text_train_padded, text_test_padded

# %%
# THIS CODE IS USED TO OVERCOME THE UNKNOWN CATEGORICAL VALUES ENCOUNTERED IN THE TEST DATA, WHEN USING Sklearn's LabelEncoder
# We basically add a 'Unknown' category when fitting, to accomodate all the unseen/unknown values in test data
# https://stackoverflow.com/a/56876351/7697658

from sklearn.preprocessing import LabelEncoder
import numpy as np

class LabelEncoderExt(object):
    def __init__(self):
        """
        It differs from LabelEncoder by handling new classes and providing a value for it [Unknown]
        Unknown will be added in fit and transform will take care of new item. It gives unknown class id
        """
        self.label_encoder = LabelEncoder()
        # self.classes_ = self.label_encoder.classes_

    def fit(self, data_list):
        """
        This will fit the encoder for all the unique values and introduce unknown value
        :param data_list: A list of string
        :return: self
        """
        self.label_encoder = self.label_encoder.fit(list(data_list) + ['Unknown'])
        self.classes_ = self.label_encoder.classes_

        return self

    def transform(self, data_list):
        """
        This will transform the data_list to id list where the new values get assigned to Unknown class
        :param data_list:
        :return:
        """
        new_data_list = list(data_list)
        for unique_item in np.unique(data_list):
            if unique_item not in self.label_encoder.classes_:
                new_data_list = ['Unknown' if x==unique_item else x for x in new_data_list]

        return self.label_encoder.transform(new_data_list)

# %%
# Why you should not use One Hot Encoding for this,
# https://stackoverflow.com/a/51184399/7697658

# Embedding categorical data,
# https://machinelearningmastery.com/how-to-prepare-categorical-data-for-deep-learning-in-python/
def categorical_embeddings(cat_train, cat_test):
    """
    This function will do Label encoding of the categorical feature.
    """
    vocab_size = len(cat_train.unique())+1
    le = LabelEncoderExt()
    le.fit(cat_train.values)
    encoded_train = le.transform(cat_train.values)
    encoded_test = le.transform(cat_test.values)

    return vocab_size, encoded_train, encoded_test

# %%
def numeric_standardizing(X_train_numeric, X_test_numeric):
    """
    This function will normalize the numeric feature.
    """
    scaler = Normalizer()
    scaler.fit(X_train_numeric.values.reshape(1,-1))

    X_train_price_scaled = scaler.transform(X_train_numeric.values.reshape(1,-1))
    X_test_price_scaled = scaler.transform(X_test_numeric.values.reshape(1,-1))
    return X_train_price_scaled.flatten(), X_test_price_scaled.flatten()

# %%
def text_model_pipeline(input_len, vocab_size, embedding_matrix, layer_name):
    """
    This function will create a sub-model of the text data using embedding layer and GRU.
    """
    input_layer = Input(shape=input_len, name=layer_name+'_input')
    e_layer = Embedding(input_dim=vocab_size, output_dim=300, weights=[embedding_matrix], input_length=input_len, trainable=False, name=layer_name+'_embedding')(input_layer)
    #e_layer = Embedding(input_dim=vocab_size, output_dim=80, trainable=True, name=layer_name+'_embedding')(input_layer)
    lstm = GRU(units=128, name=layer_name+'_lstm')(e_layer)
    #flat = Flatten()(lstm)
    #out = flat
    out = lstm
    model = Model(inputs=input_layer ,outputs=out)
    return model

def categorical_model_pipeline(input_len, vocab_size, layer_name):   # Here vocab_size will be the number of unique values in the column
    """
    This function will create a sub-model of the categorical data. It will use embedding layer to embedd the categories.
    """
    input_layer = Input(shape=input_len, name=layer_name+'_input')
    e_layer  = Embedding(input_dim=vocab_size, output_dim=32, trainable=True, name=layer_name+'_embedding')(input_layer)
    flat = Flatten()(e_layer)
    out = flat
    model = Model(inputs=input_layer ,outputs=out)
    return model

def numeric_model_pipeline(input_len, layer_name):
    """
    This function will create a sub-model of the numeric data using a single dense layer.
    """
    input_layer = Input(shape=input_len, name=layer_name+'_input')
    dense = Dense(units=32,activation='relu', name=layer_name+'_dense')(input_layer)
    out = dense
    model = Model(inputs=input_layer ,outputs=out)
    return model

def low_cardinal_categories(input_len, layer_name):
    """
    This function will create a sub-model of the low cardinal features. This just flattens the input and nothing else.
    """
    input_layer = Input(shape=input_len, name=layer_name+'_input')
    flat = Flatten()(input_layer)
    out = flat
    model = Model(inputs=input_layer ,outputs=out)
    return model

# %%
# Featurizing the input data.
X_train, scaler_name_len, scaler_desc_len = feature_pipeline(X_train, scaler_name_len=None, scaler_desc_len=None)
X_test, _, _ = feature_pipeline(X_test, scaler_name_len, scaler_desc_len)
# Out:
# Filling missing values...
# pre-processing text data...
# HBox(children=(FloatProgress(value=0.0, max=1374475.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1374475.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1374475.0), HTML(value='')))
# Guessing the missing brands...
# HBox(children=(FloatProgress(value=0.0, max=1374475.0), HTML(value='')))
# Splitting categories...
# Getting word lengths
# Getting is_expensive brand feature...
# Done!!!
# ---------------------------
#
#
# Filling missing values...
# pre-processing text data...
# HBox(children=(FloatProgress(value=0.0, max=72341.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=72341.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=72341.0), HTML(value='')))
# Guessing the missing brands...
# HBox(children=(FloatProgress(value=0.0, max=72341.0), HTML(value='')))
# Splitting categories...
# Getting word lengths
# Getting is_expensive brand feature...
# Done!!!
# ---------------------------

# %%
tf.keras.backend.clear_session()

def create_model_1(X_train, X_test):
    """
    This function creates the model structure.
    """
    ####################### Text data ######################
    desc_embedding_matrix, desc_vocab_size, desc_max_len_doc, desc_text_train_padded, desc_text_test_padded = text_embeddings(X_train['item_description'].apply(str), X_test['item_description'].apply(str))
    name_embedding_matrix, name_vocab_size, name_max_len_doc, name_text_train_padded, name_text_test_padded = text_embeddings(X_train['name'].apply(str), X_test['name'].apply(str))

    desc_flat_model = text_model_pipeline(desc_max_len_doc, desc_vocab_size, desc_embedding_matrix, 'description')
    name_flat_model = text_model_pipeline(name_max_len_doc, name_vocab_size, name_embedding_matrix, 'name')
    ########################################################


    ################### Categorical data ###################
    bn_vocab_size, bn_encoded_train, bn_encoded_test = categorical_embeddings(X_train['brand_name'], X_test['brand_name'])
    gc_vocab_size, gc_encoded_train, gc_encoded_test = categorical_embeddings(X_train['general_cat'], X_test['general_cat'])
    sc1_vocab_size, sc1_encoded_train, sc1_encoded_test = categorical_embeddings(X_train['subcat_1'], X_test['subcat_1'])
    sc2_vocab_size, sc2_encoded_train, sc2_encoded_test = categorical_embeddings(X_train['subcat_2'], X_test['subcat_2'])

    bn_flat_model = categorical_model_pipeline(1, bn_vocab_size, 'bn')
    gc_flat_model = categorical_model_pipeline(1, gc_vocab_size, 'gc')
    sc1_flat_model = categorical_model_pipeline(1, sc1_vocab_size, 'sc1')
    sc2_flat_model = categorical_model_pipeline(1, sc2_vocab_size, 'sc2')
    ic_flat_model = low_cardinal_categories(5, 'item_condition')
    sh_flat_model = low_cardinal_categories(2, 'shipping')
    is_ex_flat_model = low_cardinal_categories(2, 'isExpensive')
    #########################################################


    ################### Numeric data ###################
    numeric_train_input = pd.concat((X_train['desc_len'], X_train['name_len']), axis=1).to_numpy()
    numeric_test_input = pd.concat((X_test['desc_len'], X_test['name_len']), axis=1).to_numpy()

    numeric_model = numeric_model_pipeline(numeric_train_input.shape[1], 'numeric')
    ####################################################


    ############### Concatenating layers ###############
    combined_layers = [desc_flat_model.output, name_flat_model.output, 
                       bn_flat_model.output, gc_flat_model.output, sc1_flat_model.output, sc2_flat_model.output, ic_flat_model.output, \
                       sh_flat_model.output, is_ex_flat_model.output, numeric_model.output]
    concatenate_layer = Concatenate()(combined_layers)
    ####################################################

    dense = BatchNormalization()(concatenate_layer)
    dense = Dense(units=256, activation='relu', kernel_regularizer=regularizers.l2(0.001))(dense)
    dense = Dense(units=128, activation='relu', kernel_regularizer=regularizers.l2(0.001))(dense)
    concatenate_layer = Concatenate()([dense, ic_flat_model.output, sh_flat_model.output, is_ex_flat_model.output, numeric_model.output])
    dense = LayerNormalization(axis=1)(concatenate_layer)
    #dense = Dense(units=64, activation='relu', kernel_regularizer=regularizers.l2(0.001))(concatenate_layer)

    out = Dense(units=1, activation='linear', name='Output')(dense)

    model = Model(inputs=[desc_flat_model.input, name_flat_model.input, 
                       bn_flat_model.input, gc_flat_model.input, sc1_flat_model.input, sc2_flat_model.input, ic_flat_model.input, \
                       sh_flat_model.input, is_ex_flat_model.input, numeric_model.input], \
                  outputs=out)


    X_train_inputs = [desc_text_train_padded, name_text_train_padded, bn_encoded_train, gc_encoded_train, sc1_encoded_train, sc2_encoded_train, tf.one_hot(X_train['item_condition_id'], 5),\
                      tf.one_hot(X_train['shipping'], 2), tf.one_hot(X_train['is_expensive'], 2), numeric_train_input]
    X_test_inputs = [desc_text_test_padded, name_text_test_padded, bn_encoded_test, gc_encoded_test, sc1_encoded_test, sc2_encoded_test, tf.one_hot(X_test['item_condition_id'], 5),\
                     tf.one_hot(X_test['shipping'], 2), tf.one_hot(X_test['is_expensive'], 2), numeric_test_input]
    return model, X_train_inputs, X_test_inputs

# %%
model_1, X_train_inputs, X_test_inputs = create_model_1(X_train, X_test)
model_1.summary()
# Out:
# Model: "functional_21"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# description_input (InputLayer)  [(None, 251)]        0
# __________________________________________________________________________________________________
# name_input (InputLayer)         [(None, 13)]         0
# __________________________________________________________________________________________________
# bn_input (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# gc_input (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# sc1_input (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# sc2_input (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# description_embedding (Embeddin (None, 251, 300)     46315800    description_input[0][0]
# __________________________________________________________________________________________________
# name_embedding (Embedding)      (None, 13, 300)      30070200    name_input[0][0]
# __________________________________________________________________________________________________
# bn_embedding (Embedding)        (None, 1, 32)        150816      bn_input[0][0]
# __________________________________________________________________________________________________
# gc_embedding (Embedding)        (None, 1, 32)        384         gc_input[0][0]
# __________________________________________________________________________________________________
# sc1_embedding (Embedding)       (None, 1, 32)        3680        sc1_input[0][0]
# __________________________________________________________________________________________________
# sc2_embedding (Embedding)       (None, 1, 32)        27872       sc2_input[0][0]
# __________________________________________________________________________________________________
# item_condition_input (InputLaye [(None, 5)]          0
# __________________________________________________________________________________________________
# shipping_input (InputLayer)     [(None, 2)]          0
# __________________________________________________________________________________________________
# isExpensive_input (InputLayer)  [(None, 2)]          0
# __________________________________________________________________________________________________
# numeric_input (InputLayer)      [(None, 2)]          0
# __________________________________________________________________________________________________
# description_lstm (GRU)          (None, 128)          165120      description_embedding[0][0]
# __________________________________________________________________________________________________
# name_lstm (GRU)                 (None, 128)          165120      name_embedding[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 32)           0           bn_embedding[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 32)           0           gc_embedding[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 32)           0           sc1_embedding[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 32)           0           sc2_embedding[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 5)            0           item_condition_input[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 2)            0           shipping_input[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 2)            0           isExpensive_input[0][0]
# __________________________________________________________________________________________________
# numeric_dense (Dense)           (None, 32)           96          numeric_input[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 425)          0           description_lstm[0][0]
#                                                                  name_lstm[0][0]
#                                                                  flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
#                                                                  flatten_4[0][0]
#                                                                  flatten_5[0][0]
#                                                                  flatten_6[0][0]
#                                                                  numeric_dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 425)          1700        concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          109056      batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          32896       dense[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 169)          0           dense_1[0][0]
#                                                                  flatten_4[0][0]
#                                                                  flatten_5[0][0]
#                                                                  flatten_6[0][0]
#                                                                  numeric_dense[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 169)          338         concatenate_1[0][0]
# __________________________________________________________________________________________________
# Output (Dense)                  (None, 1)            170         layer_normalization[0][0]
# ==================================================================================================
# Total params: 77,043,248
# Trainable params: 656,398
# Non-trainable params: 76,386,850
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model=model_1, to_file='model_1_plot.png', show_shapes=True)

# %%
# For more info on ModelCheckpoint, refer https://machinelearningmastery.com/check-point-deep-learning-models-keras/
from tensorflow.keras.callbacks import ModelCheckpoint
model_path = "/content/drive/My Drive/Colab Notebooks/Applied AI Assignments/Case Study 1 Mercari Price Suggestion/zzFINAL COMPLETED/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs"
checkpoint_best = ModelCheckpoint(filepath=model_path, monitor='val_loss',verbose=1, save_best_only=True, mode='min')

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
# https://stackoverflow.com/a/42963385/7697658
lrschedule_1 = ReduceLROnPlateau(monitor='val_loss', patience=2, verbose=1, factor=0.70, mode='min')

# %%
# For more info on EarlyStoppingdelCheckpoint, refer https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/
from tensorflow.keras.callbacks import EarlyStopping
earlystop = EarlyStopping(monitor='val_loss', verbose=1, patience=5)

# %%
EPOCHS = 100
BATCH_SIZE = 1024
adam = Adam(learning_rate=0.0003)
model_1.compile(optimizer=adam, loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])

model_1_hist = model_1.fit(x=X_train_inputs, y=y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=True, validation_data=(X_test_inputs, y_test), 
                           callbacks=[checkpoint_best, lrschedule_1, earlystop])
# Out:
# Epoch 1/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.6602 - root_mean_squared_error: 0.5981
# Epoch 00001: val_loss improved from inf to 0.57250, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 182s 136ms/step - loss: 0.6601 - root_mean_squared_error: 0.5981 - val_loss: 0.5725 - val_root_mean_squared_error: 0.5911
# Epoch 2/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.4324 - root_mean_squared_error: 0.5044
# Epoch 00002: val_loss improved from 0.57250 to 0.39537, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 179s 133ms/step - loss: 0.4324 - root_mean_squared_error: 0.5044 - val_loss: 0.3954 - val_root_mean_squared_error: 0.5073
# Epoch 3/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.3484 - root_mean_squared_error: 0.4910
# Epoch 00003: val_loss improved from 0.39537 to 0.33897, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 179s 133ms/step - loss: 0.3484 - root_mean_squared_error: 0.4910 - val_loss: 0.3390 - val_root_mean_squared_error: 0.5080
# Epoch 4/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2960 - root_mean_squared_error: 0.4838
# Epoch 00004: val_loss improved from 0.33897 to 0.31971, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 182s 135ms/step - loss: 0.2960 - root_mean_squared_error: 0.4838 - val_loss: 0.3197 - val_root_mean_squared_error: 0.5232
# Epoch 5/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2651 - root_mean_squared_error: 0.4789
# Epoch 00005: val_loss improved from 0.31971 to 0.26251, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 179s 133ms/step - loss: 0.2651 - root_mean_squared_error: 0.4789 - val_loss: 0.2625 - val_root_mean_squared_error: 0.4849
# Epoch 6/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2477 - root_mean_squared_error: 0.4747
# Epoch 00006: val_loss improved from 0.26251 to 0.25188, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 182s 135ms/step - loss: 0.2477 - root_mean_squared_error: 0.4747 - val_loss: 0.2519 - val_root_mean_squared_error: 0.4835
# Epoch 7/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2379 - root_mean_squared_error: 0.4714
# Epoch 00007: val_loss improved from 0.25188 to 0.24716, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 180s 134ms/step - loss: 0.2379 - root_mean_squared_error: 0.4714 - val_loss: 0.2472 - val_root_mean_squared_error: 0.4833
# Epoch 8/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2314 - root_mean_squared_error: 0.4680
# Epoch 00008: val_loss improved from 0.24716 to 0.24160, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 180s 134ms/step - loss: 0.2315 - root_mean_squared_error: 0.4681 - val_loss: 0.2416 - val_root_mean_squared_error: 0.4800
# Epoch 9/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2267 - root_mean_squared_error: 0.4649
# Epoch 00009: val_loss did not improve from 0.24160
# 1343/1343 [==============================] - 171s 128ms/step - loss: 0.2267 - root_mean_squared_error: 0.4649 - val_loss: 0.2579 - val_root_mean_squared_error: 0.4981
# Epoch 10/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2232 - root_mean_squared_error: 0.4623
# Epoch 00010: val_loss improved from 0.24160 to 0.23837, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 180s 134ms/step - loss: 0.2232 - root_mean_squared_error: 0.4623 - val_loss: 0.2384 - val_root_mean_squared_error: 0.4790
# Epoch 11/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2201 - root_mean_squared_error: 0.4597
# Epoch 00011: val_loss did not improve from 0.23837
# 1343/1343 [==============================] - 172s 128ms/step - loss: 0.2201 - root_mean_squared_error: 0.4598 - val_loss: 0.2569 - val_root_mean_squared_error: 0.4984
# Epoch 12/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2173 - root_mean_squared_error: 0.4572
# Epoch 00012: val_loss improved from 0.23837 to 0.23561, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 179s 134ms/step - loss: 0.2173 - root_mean_squared_error: 0.4572 - val_loss: 0.2356 - val_root_mean_squared_error: 0.4770
# Epoch 13/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2152 - root_mean_squared_error: 0.4552
# Epoch 00013: val_loss improved from 0.23561 to 0.23319, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 180s 134ms/step - loss: 0.2152 - root_mean_squared_error: 0.4552 - val_loss: 0.2332 - val_root_mean_squared_error: 0.4748
# Epoch 14/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2131 - root_mean_squared_error: 0.4531
# Epoch 00014: val_loss improved from 0.23319 to 0.23170, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 181s 135ms/step - loss: 0.2131 - root_mean_squared_error: 0.4531 - val_loss: 0.2317 - val_root_mean_squared_error: 0.4734
# Epoch 15/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2112 - root_mean_squared_error: 0.4512
# Epoch 00015: val_loss did not improve from 0.23170
# 1343/1343 [==============================] - 171s 127ms/step - loss: 0.2112 - root_mean_squared_error: 0.4512 - val_loss: 0.2319 - val_root_mean_squared_error: 0.4738
# Epoch 16/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2094 - root_mean_squared_error: 0.4494
# Epoch 00016: val_loss improved from 0.23170 to 0.23096, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 180s 134ms/step - loss: 0.2094 - root_mean_squared_error: 0.4494 - val_loss: 0.2310 - val_root_mean_squared_error: 0.4729
# Epoch 17/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2080 - root_mean_squared_error: 0.4479
# Epoch 00017: val_loss improved from 0.23096 to 0.23029, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 180s 134ms/step - loss: 0.2080 - root_mean_squared_error: 0.4479 - val_loss: 0.2303 - val_root_mean_squared_error: 0.4723
# Epoch 18/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2065 - root_mean_squared_error: 0.4464
# Epoch 00018: val_loss improved from 0.23029 to 0.22942, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 182s 135ms/step - loss: 0.2065 - root_mean_squared_error: 0.4464 - val_loss: 0.2294 - val_root_mean_squared_error: 0.4715
# Epoch 19/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2050 - root_mean_squared_error: 0.4448
# Epoch 00019: val_loss improved from 0.22942 to 0.22929, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 179s 134ms/step - loss: 0.2050 - root_mean_squared_error: 0.4448 - val_loss: 0.2293 - val_root_mean_squared_error: 0.4714
# Epoch 20/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2038 - root_mean_squared_error: 0.4436
# Epoch 00020: val_loss did not improve from 0.22929
# 1343/1343 [==============================] - 172s 128ms/step - loss: 0.2038 - root_mean_squared_error: 0.4436 - val_loss: 0.2307 - val_root_mean_squared_error: 0.4729
# Epoch 21/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.2024 - root_mean_squared_error: 0.4419
# Epoch 00021: val_loss did not improve from 0.22929
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00021000000997446476.
# 1343/1343 [==============================] - 172s 128ms/step - loss: 0.2024 - root_mean_squared_error: 0.4419 - val_loss: 0.2317 - val_root_mean_squared_error: 0.4740
# Epoch 22/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1978 - root_mean_squared_error: 0.4370
# Epoch 00022: val_loss improved from 0.22929 to 0.22536, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 180s 134ms/step - loss: 0.1979 - root_mean_squared_error: 0.4370 - val_loss: 0.2254 - val_root_mean_squared_error: 0.4676
# Epoch 23/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1965 - root_mean_squared_error: 0.4356
# Epoch 00023: val_loss did not improve from 0.22536
# 1343/1343 [==============================] - 171s 128ms/step - loss: 0.1965 - root_mean_squared_error: 0.4356 - val_loss: 0.2265 - val_root_mean_squared_error: 0.4689
# Epoch 24/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1954 - root_mean_squared_error: 0.4345
# Epoch 00024: val_loss improved from 0.22536 to 0.22419, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 181s 135ms/step - loss: 0.1954 - root_mean_squared_error: 0.4345 - val_loss: 0.2242 - val_root_mean_squared_error: 0.4665
# Epoch 25/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1944 - root_mean_squared_error: 0.4334
# Epoch 00025: val_loss did not improve from 0.22419
# 1343/1343 [==============================] - 172s 128ms/step - loss: 0.1944 - root_mean_squared_error: 0.4334 - val_loss: 0.2267 - val_root_mean_squared_error: 0.4693
# Epoch 26/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1935 - root_mean_squared_error: 0.4324
# Epoch 00026: val_loss did not improve from 0.22419
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.00014700000901939346.
# 1343/1343 [==============================] - 172s 128ms/step - loss: 0.1935 - root_mean_squared_error: 0.4324 - val_loss: 0.2249 - val_root_mean_squared_error: 0.4673
# Epoch 27/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1900 - root_mean_squared_error: 0.4284
# Epoch 00027: val_loss improved from 0.22419 to 0.22251, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 180s 134ms/step - loss: 0.1900 - root_mean_squared_error: 0.4284 - val_loss: 0.2225 - val_root_mean_squared_error: 0.4649
# Epoch 28/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1890 - root_mean_squared_error: 0.4273
# Epoch 00028: val_loss did not improve from 0.22251
# 1343/1343 [==============================] - 172s 128ms/step - loss: 0.1890 - root_mean_squared_error: 0.4273 - val_loss: 0.2226 - val_root_mean_squared_error: 0.4651
# Epoch 29/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1882 - root_mean_squared_error: 0.4265
# Epoch 00029: val_loss did not improve from 0.22251
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.00010290000936947763.
# 1343/1343 [==============================] - 170s 127ms/step - loss: 0.1882 - root_mean_squared_error: 0.4265 - val_loss: 0.2235 - val_root_mean_squared_error: 0.4661
# Epoch 30/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1853 - root_mean_squared_error: 0.4232
# Epoch 00030: val_loss did not improve from 0.22251
# 1343/1343 [==============================] - 171s 127ms/step - loss: 0.1853 - root_mean_squared_error: 0.4232 - val_loss: 0.2239 - val_root_mean_squared_error: 0.4667
# Epoch 31/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1845 - root_mean_squared_error: 0.4224
# Epoch 00031: val_loss improved from 0.22251 to 0.22204, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 181s 134ms/step - loss: 0.1845 - root_mean_squared_error: 0.4224 - val_loss: 0.2220 - val_root_mean_squared_error: 0.4647
# Epoch 32/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1841 - root_mean_squared_error: 0.4219
# Epoch 00032: val_loss improved from 0.22204 to 0.22163, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 180s 134ms/step - loss: 0.1841 - root_mean_squared_error: 0.4219 - val_loss: 0.2216 - val_root_mean_squared_error: 0.4643
# Epoch 33/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1835 - root_mean_squared_error: 0.4213
# Epoch 00033: val_loss did not improve from 0.22163
# 1343/1343 [==============================] - 170s 127ms/step - loss: 0.1835 - root_mean_squared_error: 0.4213 - val_loss: 0.2243 - val_root_mean_squared_error: 0.4672
# Epoch 34/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1831 - root_mean_squared_error: 0.4208
# Epoch 00034: val_loss improved from 0.22163 to 0.22069, saving model to /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 179s 133ms/step - loss: 0.1831 - root_mean_squared_error: 0.4208 - val_loss: 0.2207 - val_root_mean_squared_error: 0.4634
# Epoch 35/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1825 - root_mean_squared_error: 0.4202
# Epoch 00035: val_loss did not improve from 0.22069
# 1343/1343 [==============================] - 172s 128ms/step - loss: 0.1825 - root_mean_squared_error: 0.4202 - val_loss: 0.2216 - val_root_mean_squared_error: 0.4644
# Epoch 36/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1821 - root_mean_squared_error: 0.4197
# Epoch 00036: val_loss did not improve from 0.22069
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 7.203000859590247e-05.
# 1343/1343 [==============================] - 171s 127ms/step - loss: 0.1821 - root_mean_squared_error: 0.4197 - val_loss: 0.2222 - val_root_mean_squared_error: 0.4651
# Epoch 37/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1799 - root_mean_squared_error: 0.4172
# Epoch 00037: val_loss did not improve from 0.22069
# 1343/1343 [==============================] - 171s 128ms/step - loss: 0.1799 - root_mean_squared_error: 0.4172 - val_loss: 0.2211 - val_root_mean_squared_error: 0.4640
# Epoch 38/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1794 - root_mean_squared_error: 0.4167
# Epoch 00038: val_loss did not improve from 0.22069
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 5.042100601713173e-05.
# 1343/1343 [==============================] - 171s 127ms/step - loss: 0.1795 - root_mean_squared_error: 0.4167 - val_loss: 0.2218 - val_root_mean_squared_error: 0.4648
# Epoch 39/100
# 1342/1343 [============================>.] - ETA: 0s - loss: 0.1778 - root_mean_squared_error: 0.4147
# Epoch 00039: val_loss did not improve from 0.22069
# 1343/1343 [==============================] - 171s 128ms/step - loss: 0.1778 - root_mean_squared_error: 0.4147 - val_loss: 0.2208 - val_root_mean_squared_error: 0.4637
# Epoch 00039: early stopping

# %% [markdown]
# #### **Test Pipeline**

# %%
# import pickle
# from sklearn.preprocessing import StandardScaler
# with open('/content/drive/My Drive/Colab Notebooks/Applied AI Assignments/Case Study 1 Mercari Price Suggestion/scaler_name_len(DL).pkl', 'rb') as f:
#     scaler_name_len = pickle.load(f)

# with open('/content/drive/My Drive/Colab Notebooks/Applied AI Assignments/Case Study 1 Mercari Price Suggestion/scaler_desc_len(DL).pkl', 'rb') as f:
#     scaler_desc_len = pickle.load(f)

# %%
test = pd.read_csv('test_stg2.tsv', sep='\t')
X_te, _, _ = feature_pipeline(test, scaler_name_len, scaler_desc_len)
# Out:
# Filling missing values...
# pre-processing text data...
# HBox(children=(FloatProgress(value=0.0, max=3460725.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3460725.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3460725.0), HTML(value='')))
# Guessing the missing brands...
# HBox(children=(FloatProgress(value=0.0, max=3460725.0), HTML(value='')))
# Splitting categories...
# Getting word lengths
# Getting is_expensive brand feature...
# Done!!!
# ---------------------------

# %%
####################### Text data ######################
_, _, _, _, desc_text_test_padded = text_embeddings(X_train['item_description'].apply(str), X_te['item_description'].apply(str))
_, _, _, _, name_text_test_padded = text_embeddings(X_train['name'].apply(str), X_te['name'].apply(str))
########################################################


################### Categorical data ###################
_, _, bn_encoded_test = categorical_embeddings(X_train['brand_name'], X_te['brand_name'])
_, _, gc_encoded_test = categorical_embeddings(X_train['general_cat'], X_te['general_cat'])
_, _, sc1_encoded_test = categorical_embeddings(X_train['subcat_1'], X_te['subcat_1'])
_, _, sc2_encoded_test = categorical_embeddings(X_train['subcat_2'], X_te['subcat_2'])
#########################################################


################### Numeric data ###################
numeric_test_input = pd.concat((X_te['desc_len'], X_te['name_len']), axis=1).to_numpy()


X_test_submission = [desc_text_test_padded, name_text_test_padded, bn_encoded_test, gc_encoded_test, sc1_encoded_test, sc2_encoded_test, tf.one_hot(X_te['item_condition_id'], 5),\
                tf.one_hot(X_te['shipping'], 2), tf.one_hot(X_te['is_expensive'], 2), numeric_test_input]

# %%
def create_submission_output_file(model, X_data, bs=64):
    submission_prices = model.predict(X_data, batch_size=bs)
    submission_prices = np.exp(submission_prices)
    submission_prices = np.squeeze(submission_prices, axis=1)
    my_submission = pd.DataFrame({'test_id': test['test_id'], 'price': submission_prices})
    my_submission.to_csv('/content/drive/My Drive/Colab Notebooks/Applied AI Assignments/Case Study 1 Mercari Price Suggestion/Submission/submission_ft_lstm_silver.csv', index=False)

# %%
model_path = "/content/drive/My Drive/Colab Notebooks/Applied AI Assignments/Case Study 1 Mercari Price Suggestion/zzFINAL COMPLETED/FAST TEXT LSTM/BEST_FT_LSTM_MODEL.hdfs"
model_best = tf.keras.models.load_model(model_path)

# %%
create_submission_output_file(model_best, X_test_submission)

# %% [markdown]
# # **Kaggle submission score**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
