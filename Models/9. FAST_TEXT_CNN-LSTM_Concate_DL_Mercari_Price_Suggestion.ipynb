# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **DATA INITIZLIZATION**

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import gc

import pandas as pd
import numpy as np
import string
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns
import math
import lightgbm as lgb
from tqdm.notebook import tqdm
tqdm.pandas()

#!pip install Wordbatch
#from wordbatch.models import FTRL, FM_FTRL  # https://github.com/anttttti/Wordbatch
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from nltk.corpus import wordnet
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from sklearn.model_selection import train_test_split
import scipy
from scipy.sparse import hstack

from sklearn.metrics import mean_squared_log_error
import pickle
import regex as re
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/My Drive/Colab/'
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
if 'train.tsv' not in os.listdir(): 
    # !kaggle competitions download -c mercari-price-suggestion-challenge
    get_ipython().system_raw("7z x \*.7z && rm *.7z")
    get_ipython().system_raw("7z x \*.zip && rm *.zip")
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.10 / client 1.5.4)
# Downloading sample_submission_stg2.csv.zip to /content
#  64% 5.00M/7.77M [00:00<00:00, 25.3MB/s]
# 100% 7.77M/7.77M [00:00<00:00, 30.9MB/s]
# Downloading test_stg2.tsv.zip to /content
#  95% 281M/294M [00:03<00:00, 111MB/s]
# 100% 294M/294M [00:03<00:00, 82.9MB/s]
# Downloading test.tsv.7z to /content
#  94% 32.0M/34.0M [00:00<00:00, 37.2MB/s]
# 100% 34.0M/34.0M [00:00<00:00, 113MB/s]
# Downloading train.tsv.7z to /content
#  71% 53.0M/74.3M [00:01<00:01, 15.2MB/s]
# 100% 74.3M/74.3M [00:02<00:00, 38.6MB/s]
# Downloading sample_submission.csv.7z to /content
#   0% 0.00/170k [00:00<?, ?B/s]
# 100% 170k/170k [00:00<00:00, 193MB/s]

# %%
import pandas as pd

train_df = pd.read_csv('train.tsv', sep='\t')

# Price range should be $5-$2000, https://www.mercari.com/us/help_center/article/69
train_df = train_df[train_df['price']>=5]  # Removing the prodicts with prices less than 5
train_df = train_df[train_df['price']<=2000]  # Removing the prodicts with prices more than 2000
train_df.head()
# Out:
#    train_id  ...                                   item_description
# 0         0  ...                                 No description yet
# 1         1  ...  This keyboard is in great condition and works ...
# 2         2  ...  Adorable top with a hint of lace and a key hol...
# 3         3  ...  New with tags. Leather horses. Retail for [rm]...
# 4         4  ...          Complete with certificate of authenticity
#
# [5 rows x 8 columns]

# %% [markdown]
# **Adding log price column**

# %%
from scipy import stats

train_df['log_price'] = np.log(train_df['price'].values)

plt.figure(figsize=(12,10))
plt.subplot(211)
sns.distplot(train_df['log_price'])

# %% [markdown]
# **Train Test Split**

# %%
X = train_df.drop(['train_id','log_price','price'], axis=1)
y = train_df['log_price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=42)
del X, y, train_df

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1374475, 6)
# (1374475,)
# (72341, 6)
# (72341,)

# %% [markdown]
# # **FEATURE ENGINEERING**

# %% [markdown]
# ### **Filling missing values**

# %%
def fill_missing_values(df):
    """
    Description:
    Filling null values in all columns.

    Input: Dataframe with null values
    Output: Dataframe with no null values
    """
    df['name'].fillna('unk_name', inplace=True)
    df['category_name'].fillna('unk_cat', inplace=True)
    df['brand_name'].fillna('unk_brand', inplace=True)
    df['item_description'].fillna('unk_descr', inplace=True)
    return df

# %% [markdown]
# ### **Text Pre-processing**

# %%
import re
import string

def decontract_text(phrase):
    """
    This utility funciton will be used as a part of preprocessing the text.
    It will expand the contracted words. For eg: won't -> will not, I'm -> I am.
    """
    phrase = str(phrase)
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

def preprocess_descriptive_text_column(sentance):
    """
    Description:
    This function will process the text data.
    This function will perform decontracting words, removing stop words, removing special characters and then apply stemming on the words in the sentence.

    Input: original sentence
    Output: processed sentence
    """
    # https://gist.github.com/sebleier/554280
    # we are removing the negative words from the stop words list: 'no', 'nor', 'not', 'shouldn't, won't, etc.
    stopwords= ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",\
                "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', \
                'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',\
                'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', \
                'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', \
                'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', \
                'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',\
                'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further',\
                'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',\
                'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', \
                's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', \
                've', 'y']

    sent = decontract_text(sentance)
    sent = sent.replace('\\r', ' ')
    sent = sent.replace('\\n', ' ')
    sent = sent.replace('\\"', ' ')
    sent = re.sub('[^A-Za-z0-9]+', ' ', sent)
    # https://gist.github.com/sebleier/554280
    sent = ' '.join(e for e in sent.split() if e.lower() not in stopwords)
    sent = sent.lower()
    return sent

# %% [markdown]
# ### **Fill Missing Brand Names**

# %%
import pickle
with open('/content/drive/My Drive/Colab/brands_list.pkl', 'rb') as f:
    existing_brands = pickle.load(f)
    
with open('/content/drive/My Drive/Colab/brand_names_categories_dict.pkl', 'rb') as f:
    brand_names_categories = pickle.load(f)

# %%
def brand_guesser(row):
    """
    Description:
    This function is used to guess the missing brand name.
    It will check for an existing brand name mentioned in the item name section. 
    We want our guess to be as close to actual as possible, \
    hence we will also check the category of the brand name that is guessed with the already mentioned category of that product. 
    If the category matches, then only we will fill that guessed brand name.

    Inputs: dataframe row with missing brand names
    Output: dataframe row with filled brand names
    """
    # In the above line, we are creating dictionary of brand name->category, wherever the brand name is missing.
    # This will be helpful to us during guessing the missing brand names.
    brand, name, cn = row
    brand = brand.lower()
    if brand=='unk_brand':
        for brand in existing_brands:
            if brand in name.lower() and cn in brand_names_categories[brand]:
                return brand
            
    return brand

# %% [markdown]
# ### **Split Categories**

# %%
def split_text(text):
    if text=='unk_cat':
        return ["No Label", "No Label", "No Label"]
    return text.split("/")

def split_categories(df):
    """
    Desription:
    This function separates the categories into its three parts. 
    Main category, Sub-category 1 and Sub-category 2
    Then it will remove the original category_name field.

    Input: Dataframe having category_name field
    Output: Dataframe with splitted categories
    """
    df['general_cat'], df['subcat_1'], df['subcat_2'] = zip(*df['category_name'].apply(lambda x: split_text(x)))
    df = df.drop('category_name', axis=1)
    return df

# %% [markdown]
# ### **Adding Item Description len and Item Name len**

# %%
from sklearn.preprocessing import StandardScaler
def get_len_feature(col_series, scaler_text_len=None):
    """
    Description:
    This funciton will calculate the word count of the text and standardize it.

    Input: Series, fitted scaler[optional; used during inference]
    Output: standardized text length for each product and object of the fitted scaler
    """
    text_len = col_series.apply(lambda x: len(x.split()))
    if scaler_text_len==None:
        scaler_text_len = StandardScaler()
        scaler_text_len.fit(text_len.values.reshape(-1, 1))
    text_len = scaler_text_len.transform(text_len.values.reshape(-1, 1))
    return text_len, scaler_text_len

# %% [markdown]
# ### **Add is_expensive**

# %%
def get_is_expensive_feature(df):
    """
    Description:
    This funciton will generate a feature which will tell if the brand is expensive or not.

    Input: Dataframe
    Output: Sparse is_expensive data
    """
    with open('/content/drive/My Drive/Colab/expensive_brands.pkl', 'rb') as f:
        expensive_brands = pickle.load(f)
    
    df['is_expensive'] = df['brand_name'].apply(lambda x: 1 if x in expensive_brands else 0)
    return df

# %% [markdown]
# ### **Feature Engineering pipeline**

# %%
def feature_pipeline(X_data, scaler_name_len=None, scaler_desc_len=None):
    """
    Description: This function will do all the feature engineering on the input X_data,
                and create a final data, ready for training.

    Input: Original input dataframe, 
                    scalers [optional: used during inference]
    Output: Featurized data
    """
    print()
    print("Filling missing values...")
    X_data = fill_missing_values(X_data)
    
    print("pre-processing text data...")
    X_data['item_description'] = X_data['item_description'].progress_apply(preprocess_descriptive_text_column) ### temp step ###
    X_data['name'] = X_data['name'].progress_apply(preprocess_descriptive_text_column)                         ### temp step ###
    X_data['brand_name'] = X_data['brand_name'].progress_apply(lambda x: str(x).lower())

    print("Guessing the missing brands...")
    X_data['brand_name'] = X_data[['brand_name','name', 'category_name']].progress_apply(brand_guesser, axis = 1)

    print("Splitting categories...")
    X_data = split_categories(X_data)

    print('Getting word lengths')
    X_data['name_len'], scaler_name_len =  get_len_feature(X_data['name'], scaler_name_len)
    X_data['desc_len'], scaler_desc_len =  get_len_feature(X_data['item_description'], scaler_desc_len)

    print("Getting is_expensive brand feature...")
    X_data = get_is_expensive_feature(X_data)

    print("Done!!!\n---------------------------\n")
    return X_data, scaler_name_len, scaler_desc_len

# %% [markdown]
# # **CNN MODEL**

# %%
from sklearn.preprocessing import Normalizer
import tensorflow as tf
from numpy import array
from numpy import asarray
from numpy import zeros
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import Input, Embedding, Conv1D, Conv2D, MaxPool1D, MaxPool2D, AveragePooling1D, GlobalAveragePooling1D, \
                                    Flatten, Dropout, Dense, BatchNormalization, LayerNormalization, concatenate
from tensorflow.keras.layers import ReLU
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.models import Model
from tensorflow.keras import initializers, regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM, GRU

# %%
# THIS CODE IS USED TO OVERCOME THE UNKNOWN CATEGORICAL VALUES ENCOUNTERED IN THE TEST DATA, WHEN USING Sklearn's LabelEncoder
# We basically add a 'Unknown' category when fitting, to accomodate all the unseen/unknown values in test data
# https://stackoverflow.com/a/56876351/7697658

from sklearn.preprocessing import LabelEncoder
import numpy as np

class LabelEncoderExt(object):
    def __init__(self):
        """
        It differs from LabelEncoder by handling new classes and providing a value for it [Unknown]
        Unknown will be added in fit and transform will take care of new item. It gives unknown class id
        """
        self.label_encoder = LabelEncoder()
        # self.classes_ = self.label_encoder.classes_

    def fit(self, data_list):
        """
        This will fit the encoder for all the unique values and introduce unknown value
        :param data_list: A list of string
        :return: self
        """
        self.label_encoder = self.label_encoder.fit(list(data_list) + ['Unknown'])
        self.classes_ = self.label_encoder.classes_

        return self

    def transform(self, data_list):
        """
        This will transform the data_list to id list where the new values get assigned to Unknown class
        :param data_list:
        :return:
        """
        new_data_list = list(data_list)
        for unique_item in np.unique(data_list):
            if unique_item not in self.label_encoder.classes_:
                new_data_list = ['Unknown' if x==unique_item else x for x in new_data_list]

        return self.label_encoder.transform(new_data_list)

# %%
# Why you should not use One Hot Encoding for this,
# https://stackoverflow.com/a/51184399/7697658

# Embedding categorical data,
# https://machinelearningmastery.com/how-to-prepare-categorical-data-for-deep-learning-in-python/
def categorical_embeddings(cat_train, cat_test):
    """
    This function will do Label encoding of the categorical feature.
    """
    vocab_size = len(cat_train.unique())+1
    le = LabelEncoderExt()
    le.fit(cat_train.values)
    encoded_train = le.transform(cat_train.values)
    encoded_test = le.transform(cat_test.values)

    return vocab_size, encoded_train, encoded_test

#vocab_size, encoded_train, encoded_test = categorical_embeddings(X_train['project_subject_subcategories'], X_test['project_subject_subcategories'])

# %%
# How does embedding layer work,
# https://stats.stackexchange.com/questions/270546/how-does-keras-embedding-layer-work

def text_embeddings(text_train, text_test):
    """
    This function does the tokenizing, padding, creating vocab and creating the embedding matrix for text data
    """
    # Word Tokenizer
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(text_train)
    encoded_docs_train = tokenizer.texts_to_sequences(text_train)

    encoded_docs_test = tokenizer.texts_to_sequences(text_test)

    # Getting the 'max len' of doc among the text_train
    len_docs = []
    for doc in text_train:
        splitted_doc = doc.split()
        len_docs.append(len(splitted_doc))
    max_len_doc = max(len_docs)
    #print('max doc len=',max_len_doc) # in terms of words

    text_train_padded = pad_sequences(encoded_docs_train, maxlen=max_len_doc, padding='post')
    text_test_padded = pad_sequences(encoded_docs_test, maxlen=max_len_doc, padding='post')

    vocab_size = len(tokenizer.word_index) + 1
    #print(vocab_size)

    embeddings_index = dict()
    with open('/content/drive/My Drive/Colab/wiki-news-300d-1M.vec') as f:
        for line in f:
            w_coef = line.rstrip().rsplit(' ')
            word = w_coef[0]
            coefs = asarray(w_coef[1:], dtype='float32')
            embeddings_index[word]=coefs

    embedding_matrix = zeros((vocab_size, 300))
    for word, i in tokenizer.word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
    
    return embedding_matrix, vocab_size, max_len_doc, text_train_padded, text_test_padded

# %%
def text_model_pipeline(input_len, vocab_size, embedding_matrix, layer_name):
    """
    This function will create a sub-model of the text data using embedding layer, 1D CNN, Maxpooling.
    """
    input_layer = Input(shape=input_len, name=layer_name+'_input')
    e_layer = Embedding(input_dim=vocab_size, output_dim=300, weights=[embedding_matrix], input_length=input_len, trainable=False, name=layer_name+'_embedding')(input_layer)

    conv_1 = Conv1D(filters=256, kernel_size=3, strides=1, padding='same', kernel_initializer=initializers.glorot_normal(seed=0), 
                activation='relu', kernel_regularizer=regularizers.l2(),name=layer_name+'Conv_1')(e_layer)
    conv_1 = MaxPool1D(pool_size=20, strides=1, padding='same', name=layer_name+'Maxpool_1')(conv_1)
    gru_1 = LSTM(units=256, name=layer_name+'GRU_1')(conv_1)

    conv_2 = Conv1D(filters=128, kernel_size=5, strides=1, padding='same', kernel_initializer=initializers.glorot_normal(seed=0), 
                activation='relu', kernel_regularizer=regularizers.l2(),name=layer_name+'Conv_2')(e_layer)
    conv_2 = MaxPool1D(pool_size=5, strides=1, padding='same', name=layer_name+'Maxpool_2')(conv_2)
    gru_2 = LSTM(units=128, name=layer_name+'GRU_2')(conv_2)

    conv_3 = Conv1D(filters=64, kernel_size=7, strides=1, padding='same', kernel_initializer=initializers.glorot_normal(seed=0), 
                activation='relu', kernel_regularizer=regularizers.l2(),name=layer_name+'Conv_3')(e_layer)
    conv_3 = MaxPool1D(pool_size=10, strides=1, padding='same', name=layer_name+'Maxpool_3')(conv_3)
    gru_3 = LSTM(units=64, name=layer_name+'GRU_3')(conv_3)

    concatenate_layer = concatenate([gru_1, gru_2, gru_3])

    out = concatenate_layer
    model = Model(inputs=input_layer ,outputs=out)
    return model

def categorical_model_pipeline(input_len, vocab_size, layer_name):   # Here vocab_size will be the number of unique values in the column
    """
    This function will create a sub-model of the categorical data. It will use embedding layer to embedd the categories.
    """
    input_layer = Input(shape=input_len, name=layer_name+'_input')
    e_layer  = Embedding(input_dim=vocab_size, output_dim=32, input_length=input_len, trainable=True, name=layer_name+'_embedding')(input_layer)
    flat = Flatten()(e_layer)
    out = flat
    model = Model(inputs=input_layer ,outputs=out)
    return model

def numeric_model_pipeline(input_len, layer_name):
    """
    This function will create a sub-model of the numeric data using a single dense layer.
    """
    input_layer = Input(shape=input_len, name=layer_name+'_input')
    dense = Dense(units=32,activation='relu', name=layer_name+'_dense')(input_layer)
    out = dense
    model = Model(inputs=input_layer ,outputs=out)
    return model

def low_cardinal_categories(input_len, layer_name):
    """
    This function will create a sub-model of the low cardinal features. This just flattens the input and nothing else.
    """
    input_layer = Input(shape=input_len, name=layer_name+'_input')
    flat = Flatten()(input_layer)
    out = flat
    model = Model(inputs=input_layer ,outputs=out)
    return model

# %%
tf.keras.backend.clear_session()

def create_model(X_train, X_test):
    """
    This function creates the model structure.
    """
    ####################### Text data ######################
    desc_embedding_matrix, desc_vocab_size, desc_max_len_doc, desc_text_train_padded, desc_text_test_padded = text_embeddings(X_train['item_description'].apply(str), X_test['item_description'].apply(str))
    name_embedding_matrix, name_vocab_size, name_max_len_doc, name_text_train_padded, name_text_test_padded = text_embeddings(X_train['name'].apply(str), X_test['name'].apply(str))

    desc_flat_model = text_model_pipeline(desc_max_len_doc, desc_vocab_size, desc_embedding_matrix, 'description')
    name_flat_model = text_model_pipeline(name_max_len_doc, name_vocab_size, name_embedding_matrix, 'name')
    ########################################################


    ################### Categorical data ###################
    bn_vocab_size, bn_encoded_train, bn_encoded_test = categorical_embeddings(X_train['brand_name'], X_test['brand_name'])
    gc_vocab_size, gc_encoded_train, gc_encoded_test = categorical_embeddings(X_train['general_cat'], X_test['general_cat'])
    sc1_vocab_size, sc1_encoded_train, sc1_encoded_test = categorical_embeddings(X_train['subcat_1'], X_test['subcat_1'])
    sc2_vocab_size, sc2_encoded_train, sc2_encoded_test = categorical_embeddings(X_train['subcat_2'], X_test['subcat_2'])

    bn_flat_model = categorical_model_pipeline(1, bn_vocab_size, 'bn')
    gc_flat_model = categorical_model_pipeline(1, gc_vocab_size, 'gc')
    sc1_flat_model = categorical_model_pipeline(1, sc1_vocab_size, 'sc1')
    sc2_flat_model = categorical_model_pipeline(1, sc2_vocab_size, 'sc2')
    ic_flat_model = low_cardinal_categories(5, 'item_condition')
    sh_flat_model = low_cardinal_categories(2, 'shipping')
    is_ex_flat_model = low_cardinal_categories(2, 'isExpensive')
    #########################################################


    ################### Numeric data ###################
    numeric_train_input = pd.concat((X_train['desc_len'], X_train['name_len']), axis=1).to_numpy()
    numeric_test_input = pd.concat((X_test['desc_len'], X_test['name_len']), axis=1).to_numpy()

    numeric_model = numeric_model_pipeline(numeric_train_input.shape[1], 'numeric')
    ####################################################


    ############### Concatenating layers ###############
    combined_layers = [desc_flat_model.output, name_flat_model.output, 
                       bn_flat_model.output, gc_flat_model.output, sc1_flat_model.output, sc2_flat_model.output, ic_flat_model.output, \
                       sh_flat_model.output, is_ex_flat_model.output, numeric_model.output]
    concatenate_layer = concatenate(combined_layers)
    ####################################################

    dense = BatchNormalization()(concatenate_layer)
    dense = Dense(units=256, activation='relu', kernel_regularizer=regularizers.l2(0.0001))(dense)
    #dense = Dropout(0.15)(dense)    ######
    dense = Dense(units=128, activation='relu', kernel_regularizer=regularizers.l2(0.0001))(dense)
    concatenate_layer = concatenate([dense, ic_flat_model.output, sh_flat_model.output, is_ex_flat_model.output, numeric_model.output])
    dense = LayerNormalization(axis=1)(concatenate_layer)
    #dense = Dense(units=16, activation='relu', kernel_regularizer=regularizers.l2(0.0001))(dense)       #####

    out = Dense(units=1, activation='linear', name='Output')(dense)

    model = Model(inputs=[desc_flat_model.input, name_flat_model.input, 
                       bn_flat_model.input, gc_flat_model.input, sc1_flat_model.input, sc2_flat_model.input, ic_flat_model.input, \
                       sh_flat_model.input, is_ex_flat_model.input, numeric_model.input], \
                  outputs=out)


    X_train_inputs = [desc_text_train_padded, name_text_train_padded, bn_encoded_train, gc_encoded_train, sc1_encoded_train, sc2_encoded_train, tf.one_hot(X_train['item_condition_id'], 5),\
                      tf.one_hot(X_train['shipping'], 2), tf.one_hot(X_train['is_expensive'], 2), numeric_train_input]
    X_test_inputs = [desc_text_test_padded, name_text_test_padded, bn_encoded_test, gc_encoded_test, sc1_encoded_test, sc2_encoded_test, tf.one_hot(X_test['item_condition_id'], 5),\
                     tf.one_hot(X_test['shipping'], 2), tf.one_hot(X_test['is_expensive'], 2), numeric_test_input]
    return model, X_train_inputs, X_test_inputs

# %%
X_train, scaler_name_len, scaler_desc_len = feature_pipeline(X_train, scaler_name_len=None, scaler_desc_len=None)
X_test, _, _ = feature_pipeline(X_test, scaler_name_len, scaler_desc_len)

# %%
# X_train.to_csv('/content/drive/My Drive/Colab/CNN_X_train.csv', index=False)
# X_test.to_csv('/content/drive/My Drive/Colab/CNN_X_test.csv', index=False)

# %%
X_train = pd.read_csv('/content/drive/My Drive/Colab/DL_data/CNN_X_train.csv')
X_test = pd.read_csv('/content/drive/My Drive/Colab/DL_data/CNN_X_test.csv')

# %%
model_2, X_train_inputs, X_test_inputs = create_model(X_train, X_test)
model_2.summary()
# Out:
# Model: "functional_21"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# description_input (InputLayer)  [(None, 251)]        0
# __________________________________________________________________________________________________
# name_input (InputLayer)         [(None, 13)]         0
# __________________________________________________________________________________________________
# description_embedding (Embeddin (None, 251, 300)     46315800    description_input[0][0]
# __________________________________________________________________________________________________
# name_embedding (Embedding)      (None, 13, 300)      30070200    name_input[0][0]
# __________________________________________________________________________________________________
# descriptionConv_1 (Conv1D)      (None, 251, 256)     230656      description_embedding[0][0]
# __________________________________________________________________________________________________
# descriptionConv_2 (Conv1D)      (None, 251, 128)     192128      description_embedding[0][0]
# __________________________________________________________________________________________________
# descriptionConv_3 (Conv1D)      (None, 251, 64)      134464      description_embedding[0][0]
# __________________________________________________________________________________________________
# nameConv_1 (Conv1D)             (None, 13, 256)      230656      name_embedding[0][0]
# __________________________________________________________________________________________________
# nameConv_2 (Conv1D)             (None, 13, 128)      192128      name_embedding[0][0]
# __________________________________________________________________________________________________
# nameConv_3 (Conv1D)             (None, 13, 64)       134464      name_embedding[0][0]
# __________________________________________________________________________________________________
# descriptionMaxpool_1 (MaxPoolin (None, 251, 256)     0           descriptionConv_1[0][0]
# __________________________________________________________________________________________________
# descriptionMaxpool_2 (MaxPoolin (None, 251, 128)     0           descriptionConv_2[0][0]
# __________________________________________________________________________________________________
# descriptionMaxpool_3 (MaxPoolin (None, 251, 64)      0           descriptionConv_3[0][0]
# __________________________________________________________________________________________________
# nameMaxpool_1 (MaxPooling1D)    (None, 13, 256)      0           nameConv_1[0][0]
# __________________________________________________________________________________________________
# nameMaxpool_2 (MaxPooling1D)    (None, 13, 128)      0           nameConv_2[0][0]
# __________________________________________________________________________________________________
# nameMaxpool_3 (MaxPooling1D)    (None, 13, 64)       0           nameConv_3[0][0]
# __________________________________________________________________________________________________
# bn_input (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# gc_input (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# sc1_input (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# sc2_input (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# descriptionGRU_1 (LSTM)         (None, 256)          525312      descriptionMaxpool_1[0][0]
# __________________________________________________________________________________________________
# descriptionGRU_2 (LSTM)         (None, 128)          131584      descriptionMaxpool_2[0][0]
# __________________________________________________________________________________________________
# descriptionGRU_3 (LSTM)         (None, 64)           33024       descriptionMaxpool_3[0][0]
# __________________________________________________________________________________________________
# nameGRU_1 (LSTM)                (None, 256)          525312      nameMaxpool_1[0][0]
# __________________________________________________________________________________________________
# nameGRU_2 (LSTM)                (None, 128)          131584      nameMaxpool_2[0][0]
# __________________________________________________________________________________________________
# nameGRU_3 (LSTM)                (None, 64)           33024       nameMaxpool_3[0][0]
# __________________________________________________________________________________________________
# bn_embedding (Embedding)        (None, 1, 32)        150816      bn_input[0][0]
# __________________________________________________________________________________________________
# gc_embedding (Embedding)        (None, 1, 32)        384         gc_input[0][0]
# __________________________________________________________________________________________________
# sc1_embedding (Embedding)       (None, 1, 32)        3680        sc1_input[0][0]
# __________________________________________________________________________________________________
# sc2_embedding (Embedding)       (None, 1, 32)        27872       sc2_input[0][0]
# __________________________________________________________________________________________________
# item_condition_input (InputLaye [(None, 5)]          0
# __________________________________________________________________________________________________
# shipping_input (InputLayer)     [(None, 2)]          0
# __________________________________________________________________________________________________
# isExpensive_input (InputLayer)  [(None, 2)]          0
# __________________________________________________________________________________________________
# numeric_input (InputLayer)      [(None, 2)]          0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 448)          0           descriptionGRU_1[0][0]
#                                                                  descriptionGRU_2[0][0]
#                                                                  descriptionGRU_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 448)          0           nameGRU_1[0][0]
#                                                                  nameGRU_2[0][0]
#                                                                  nameGRU_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 32)           0           bn_embedding[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 32)           0           gc_embedding[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 32)           0           sc1_embedding[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 32)           0           sc2_embedding[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 5)            0           item_condition_input[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 2)            0           shipping_input[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 2)            0           isExpensive_input[0][0]
# __________________________________________________________________________________________________
# numeric_dense (Dense)           (None, 32)           96          numeric_input[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1065)         0           concatenate[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
#                                                                  flatten_4[0][0]
#                                                                  flatten_5[0][0]
#                                                                  flatten_6[0][0]
#                                                                  numeric_dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 1065)         4260        concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          272896      batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          32896       dense[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 169)          0           dense_1[0][0]
#                                                                  flatten_4[0][0]
#                                                                  flatten_5[0][0]
#                                                                  flatten_6[0][0]
#                                                                  numeric_dense[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 169)          338         concatenate_3[0][0]
# __________________________________________________________________________________________________
# Output (Dense)                  (None, 1)            170         layer_normalization[0][0]
# ==================================================================================================
# Total params: 79,373,744
# Trainable params: 2,985,614
# Non-trainable params: 76,388,130
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model=model_2, to_file='model_2_plot.png', show_shapes=True)

# %%
# For more info on ModelCheckpoint, refer https://machinelearningmastery.com/check-point-deep-learning-models-keras/
from tensorflow.keras.callbacks import ModelCheckpoint
model_path = "/content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs"
checkpoint_best = ModelCheckpoint(filepath=model_path, monitor='val_loss',verbose=1, save_best_only=True, mode='min')

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
# https://stackoverflow.com/a/42963385/7697658
lrschedule_1 = ReduceLROnPlateau(monitor='val_loss', patience=2, verbose=1, factor=0.70, mode='min')

# %%
# For more info on EarlyStoppingdelCheckpoint, refer https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/
from tensorflow.keras.callbacks import EarlyStopping
earlystop = EarlyStopping(monitor='val_loss', verbose=1, patience=5)

# %%
EPOCHS = 60
BATCH_SIZE = 1024
adam = Adam(learning_rate=0.0003)
model_2.compile(optimizer=adam, loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])

model_2_hist = model_2.fit(x=X_train_inputs, y=y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=True, validation_data=(X_test_inputs, y_test), 
                            callbacks=[checkpoint_best, lrschedule_1, earlystop])
# Out:
# Epoch 1/60
# 1343/1343 [==============================] - ETA: 0s - loss: 1.2363 - root_mean_squared_error: 0.5420
# Epoch 00001: val_loss improved from inf to 0.32743, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 664s 494ms/step - loss: 1.2363 - root_mean_squared_error: 0.5420 - val_loss: 0.3274 - val_root_mean_squared_error: 0.5114
# Epoch 2/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.3030 - root_mean_squared_error: 0.4933
# Epoch 00002: val_loss improved from 0.32743 to 0.29803, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 662s 493ms/step - loss: 0.3030 - root_mean_squared_error: 0.4933 - val_loss: 0.2980 - val_root_mean_squared_error: 0.4943
# Epoch 3/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2847 - root_mean_squared_error: 0.4853
# Epoch 00003: val_loss improved from 0.29803 to 0.28767, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 661s 492ms/step - loss: 0.2847 - root_mean_squared_error: 0.4853 - val_loss: 0.2877 - val_root_mean_squared_error: 0.4934
# Epoch 4/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2718 - root_mean_squared_error: 0.4805
# Epoch 00004: val_loss improved from 0.28767 to 0.27662, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 662s 493ms/step - loss: 0.2718 - root_mean_squared_error: 0.4805 - val_loss: 0.2766 - val_root_mean_squared_error: 0.4892
# Epoch 5/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2630 - root_mean_squared_error: 0.4769
# Epoch 00005: val_loss improved from 0.27662 to 0.27471, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 661s 492ms/step - loss: 0.2630 - root_mean_squared_error: 0.4769 - val_loss: 0.2747 - val_root_mean_squared_error: 0.4914
# Epoch 6/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2567 - root_mean_squared_error: 0.4742
# Epoch 00006: val_loss improved from 0.27471 to 0.26658, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 663s 494ms/step - loss: 0.2567 - root_mean_squared_error: 0.4742 - val_loss: 0.2666 - val_root_mean_squared_error: 0.4862
# Epoch 7/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2522 - root_mean_squared_error: 0.4718
# Epoch 00007: val_loss improved from 0.26658 to 0.26610, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 662s 493ms/step - loss: 0.2522 - root_mean_squared_error: 0.4718 - val_loss: 0.2661 - val_root_mean_squared_error: 0.4873
# Epoch 8/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2488 - root_mean_squared_error: 0.4699
# Epoch 00008: val_loss improved from 0.26610 to 0.26532, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 662s 493ms/step - loss: 0.2488 - root_mean_squared_error: 0.4699 - val_loss: 0.2653 - val_root_mean_squared_error: 0.4881
# Epoch 9/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2458 - root_mean_squared_error: 0.4679
# Epoch 00009: val_loss improved from 0.26532 to 0.26199, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 662s 493ms/step - loss: 0.2458 - root_mean_squared_error: 0.4679 - val_loss: 0.2620 - val_root_mean_squared_error: 0.4856
# Epoch 10/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2434 - root_mean_squared_error: 0.4665
# Epoch 00010: val_loss did not improve from 0.26199
# 1343/1343 [==============================] - 633s 472ms/step - loss: 0.2434 - root_mean_squared_error: 0.4665 - val_loss: 0.2652 - val_root_mean_squared_error: 0.4900
# Epoch 11/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2417 - root_mean_squared_error: 0.4653
# Epoch 00011: val_loss did not improve from 0.26199
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00021000000997446476.
# 1343/1343 [==============================] - 633s 472ms/step - loss: 0.2417 - root_mean_squared_error: 0.4653 - val_loss: 0.2647 - val_root_mean_squared_error: 0.4900
# Epoch 12/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2329 - root_mean_squared_error: 0.4585
# Epoch 00012: val_loss improved from 0.26199 to 0.25111, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 661s 492ms/step - loss: 0.2329 - root_mean_squared_error: 0.4585 - val_loss: 0.2511 - val_root_mean_squared_error: 0.4783
# Epoch 13/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2302 - root_mean_squared_error: 0.4564
# Epoch 00013: val_loss did not improve from 0.25111
# 1343/1343 [==============================] - 633s 472ms/step - loss: 0.2302 - root_mean_squared_error: 0.4564 - val_loss: 0.2538 - val_root_mean_squared_error: 0.4822
# Epoch 14/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2284 - root_mean_squared_error: 0.4549
# Epoch 00014: val_loss did not improve from 0.25111
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00014700000901939346.
# 1343/1343 [==============================] - 633s 472ms/step - loss: 0.2284 - root_mean_squared_error: 0.4549 - val_loss: 0.2538 - val_root_mean_squared_error: 0.4818
# Epoch 15/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2210 - root_mean_squared_error: 0.4485
# Epoch 00015: val_loss improved from 0.25111 to 0.24398, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 662s 493ms/step - loss: 0.2210 - root_mean_squared_error: 0.4485 - val_loss: 0.2440 - val_root_mean_squared_error: 0.4740
# Epoch 16/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2186 - root_mean_squared_error: 0.4465
# Epoch 00016: val_loss improved from 0.24398 to 0.24357, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 662s 493ms/step - loss: 0.2186 - root_mean_squared_error: 0.4465 - val_loss: 0.2436 - val_root_mean_squared_error: 0.4742
# Epoch 17/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2172 - root_mean_squared_error: 0.4452
# Epoch 00017: val_loss did not improve from 0.24357
# 1343/1343 [==============================] - 633s 472ms/step - loss: 0.2172 - root_mean_squared_error: 0.4452 - val_loss: 0.2482 - val_root_mean_squared_error: 0.4790
# Epoch 18/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2161 - root_mean_squared_error: 0.4441
# Epoch 00018: val_loss did not improve from 0.24357
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00010290000936947763.
# 1343/1343 [==============================] - 633s 471ms/step - loss: 0.2161 - root_mean_squared_error: 0.4441 - val_loss: 0.2441 - val_root_mean_squared_error: 0.4746
# Epoch 19/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2097 - root_mean_squared_error: 0.4380
# Epoch 00019: val_loss improved from 0.24357 to 0.23972, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 662s 493ms/step - loss: 0.2097 - root_mean_squared_error: 0.4380 - val_loss: 0.2397 - val_root_mean_squared_error: 0.4715
# Epoch 20/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2076 - root_mean_squared_error: 0.4363
# Epoch 00020: val_loss did not improve from 0.23972
# 1343/1343 [==============================] - 633s 471ms/step - loss: 0.2076 - root_mean_squared_error: 0.4363 - val_loss: 0.2408 - val_root_mean_squared_error: 0.4731
# Epoch 21/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2066 - root_mean_squared_error: 0.4353
# Epoch 00021: val_loss did not improve from 0.23972
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 7.203000859590247e-05.
# 1343/1343 [==============================] - 633s 472ms/step - loss: 0.2066 - root_mean_squared_error: 0.4353 - val_loss: 0.2422 - val_root_mean_squared_error: 0.4745
# Epoch 22/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.2011 - root_mean_squared_error: 0.4297
# Epoch 00022: val_loss did not improve from 0.23972
# 1343/1343 [==============================] - 633s 472ms/step - loss: 0.2011 - root_mean_squared_error: 0.4297 - val_loss: 0.2418 - val_root_mean_squared_error: 0.4750
# Epoch 23/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1994 - root_mean_squared_error: 0.4283
# Epoch 00023: val_loss improved from 0.23972 to 0.23750, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 663s 494ms/step - loss: 0.1994 - root_mean_squared_error: 0.4283 - val_loss: 0.2375 - val_root_mean_squared_error: 0.4709
# Epoch 24/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1981 - root_mean_squared_error: 0.4271
# Epoch 00024: val_loss did not improve from 0.23750
# 1343/1343 [==============================] - 633s 472ms/step - loss: 0.1981 - root_mean_squared_error: 0.4271 - val_loss: 0.2379 - val_root_mean_squared_error: 0.4715
# Epoch 25/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1972 - root_mean_squared_error: 0.4262
# Epoch 00025: val_loss did not improve from 0.23750
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 5.042100601713173e-05.
# 1343/1343 [==============================] - 633s 472ms/step - loss: 0.1972 - root_mean_squared_error: 0.4262 - val_loss: 0.2391 - val_root_mean_squared_error: 0.4728
# Epoch 26/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1926 - root_mean_squared_error: 0.4212
# Epoch 00026: val_loss improved from 0.23750 to 0.23513, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 661s 492ms/step - loss: 0.1926 - root_mean_squared_error: 0.4212 - val_loss: 0.2351 - val_root_mean_squared_error: 0.4691
# Epoch 27/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1912 - root_mean_squared_error: 0.4200
# Epoch 00027: val_loss did not improve from 0.23513
# 1343/1343 [==============================] - 634s 472ms/step - loss: 0.1912 - root_mean_squared_error: 0.4200 - val_loss: 0.2353 - val_root_mean_squared_error: 0.4697
# Epoch 28/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1904 - root_mean_squared_error: 0.4192
# Epoch 00028: val_loss did not improve from 0.23513
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 3.5294705230626275e-05.
# 1343/1343 [==============================] - 633s 472ms/step - loss: 0.1904 - root_mean_squared_error: 0.4192 - val_loss: 0.2353 - val_root_mean_squared_error: 0.4699
# Epoch 29/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1865 - root_mean_squared_error: 0.4149
# Epoch 00029: val_loss improved from 0.23513 to 0.23300, saving model to /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs/assets
# 1343/1343 [==============================] - 661s 492ms/step - loss: 0.1865 - root_mean_squared_error: 0.4149 - val_loss: 0.2330 - val_root_mean_squared_error: 0.4678
# Epoch 30/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1853 - root_mean_squared_error: 0.4138
# Epoch 00030: val_loss did not improve from 0.23300
# 1343/1343 [==============================] - 633s 472ms/step - loss: 0.1853 - root_mean_squared_error: 0.4138 - val_loss: 0.2338 - val_root_mean_squared_error: 0.4689
# Epoch 31/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1845 - root_mean_squared_error: 0.4131
# Epoch 00031: val_loss did not improve from 0.23300
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 2.4706294425413944e-05.
# 1343/1343 [==============================] - 634s 472ms/step - loss: 0.1845 - root_mean_squared_error: 0.4131 - val_loss: 0.2350 - val_root_mean_squared_error: 0.4704
# Epoch 32/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1813 - root_mean_squared_error: 0.4095
# Epoch 00032: val_loss did not improve from 0.23300
# 1343/1343 [==============================] - 633s 472ms/step - loss: 0.1813 - root_mean_squared_error: 0.4095 - val_loss: 0.2352 - val_root_mean_squared_error: 0.4709
# Epoch 33/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1803 - root_mean_squared_error: 0.4086
# Epoch 00033: val_loss did not improve from 0.23300
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.729440609778976e-05.
# 1343/1343 [==============================] - 634s 472ms/step - loss: 0.1803 - root_mean_squared_error: 0.4086 - val_loss: 0.2332 - val_root_mean_squared_error: 0.4690
# Epoch 34/60
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1777 - root_mean_squared_error: 0.4056
# Epoch 00034: val_loss did not improve from 0.23300
# 1343/1343 [==============================] - 633s 472ms/step - loss: 0.1777 - root_mean_squared_error: 0.4056 - val_loss: 0.2346 - val_root_mean_squared_error: 0.4706
# Epoch 00034: early stopping

# %%
# YES Normalization

# %%
# Glove CNN = 0.21801/0.4551; Embeddings Trainable=True

# %% [markdown]
# ### **Test Pipeline**

# %%
with open('/content/drive/My Drive/Colab/DL_data/scalers.pkl', 'rb') as f:
    scaler_name_len, scaler_desc_len = pickle.load(f)

# %%
test = pd.read_csv('test_stg2.tsv', sep='\t')
X_te, _, _ = feature_pipeline(test, scaler_name_len, scaler_desc_len)
# Out:
# Filling missing values...
# pre-processing text data...
# HBox(children=(FloatProgress(value=0.0, max=3460725.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3460725.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3460725.0), HTML(value='')))
# Guessing the missing brands...
# HBox(children=(FloatProgress(value=0.0, max=3460725.0), HTML(value='')))
# Splitting categories...
# Getting word lengths
# Getting is_expensive brand feature...
# Done!!!
# ---------------------------

# %%
X_te.to_csv('/content/drive/My Drive/Colab/DL_data/X_te_submission.csv', index=False)

# %%
X_te = pd.read_csv('/content/drive/My Drive/Colab/DL_data/X_te_submission.csv')

# %%
####################### Text data ######################
_, _, _, _, desc_text_test_padded = text_embeddings(X_train['item_description'].apply(str), X_te['item_description'].apply(str))
_, _, _, _, name_text_test_padded = text_embeddings(X_train['name'].apply(str), X_te['name'].apply(str))
########################################################


################### Categorical data ###################
_, _, bn_encoded_test = categorical_embeddings(X_train['brand_name'], X_te['brand_name'])
_, _, gc_encoded_test = categorical_embeddings(X_train['general_cat'], X_te['general_cat'])
_, _, sc1_encoded_test = categorical_embeddings(X_train['subcat_1'], X_te['subcat_1'])
_, _, sc2_encoded_test = categorical_embeddings(X_train['subcat_2'], X_te['subcat_2'])
#########################################################


################### Numeric data ###################
numeric_test_input = pd.concat((X_te['desc_len'], X_te['name_len']), axis=1).to_numpy()


X_test_submission = [desc_text_test_padded, name_text_test_padded, bn_encoded_test, gc_encoded_test, sc1_encoded_test, sc2_encoded_test, tf.one_hot(X_te['item_condition_id'], 5),\
                tf.one_hot(X_te['shipping'], 2), tf.one_hot(X_te['is_expensive'], 2), numeric_test_input]

# %%
with open('/content/drive/My Drive/Colab/DL_data/X_test_submission.pkl', 'wb') as f:
    pickle.dump(X_test_submission, f)

# %%
def create_submission_output_file(model, X_data, bs=64):
    submission_prices = model.predict(X_data, batch_size=bs)
    submission_prices = np.exp(submission_prices)
    submission_prices = np.squeeze(submission_prices, axis=1)
    my_submission = pd.DataFrame({'test_id': test['test_id'], 'price': submission_prices})
    my_submission.to_csv("/content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/submission_ft_cnn_lstm_concate.csv", index=False)

# %%
model_path = "/content/drive/My Drive/Colab/FAST TEXT CNN-LSTM/BEST_FT_CNN_LSTM_MODEL.hdfs"
model_best = tf.keras.models.load_model(model_path)

# %%
create_submission_output_file(model_best, X_test_submission)

# %% [markdown]
# # **Kaggle Submission Score**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
